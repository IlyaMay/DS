# %% [markdown]
# <a id='h0'><a><h2>Анализ игровой индустрии</h2>

# %% [markdown]
# <div style="border:solid SkyBlue 2px; padding: 40px">
# Привет!👋
# Меня зовут Илья.
#
# Свои комментарии, по примеру прошлого проекта, я буду выделять  <font color='SkyBlue'>Голубым цветом</font>.
#
#
# <div class="alert alert-info">
# Вот он мой комментарий)
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid black; padding: 15px;">
# <b>Привет, Илья 👋</b>
# <p>Меня зовут Данила Тарасов, я - ревьюер твоего проекта. Перейдём сразу на «ты», если не против. </p>
# <p>При проверке я буду использовать следующие виды комментариев 🚦:</p>
# <hr>
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Важные замечания, без отработки которых проект не будет принят </div>
# </div>
# <hr>
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Замечания и рекомендации, необязательные к отработке (если их не больше 3-х) </div>
# </div>
# <hr>
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отличные решения и идеи, которые можно и нужно использовать в будущем </div>
# </div>
#
# <hr>
#
# Предлагаю работать над проектом в диалоге: **Комментарии, если ты что-то меняешь в проекте, хочешь задать вопрос или отвечаешь мне, прошу выделить каким-нибудь цветом, кроме тех, что я использовал выше.** Как вариант, можешь обозначить их так:
#
# <hr>
#
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-block alert-info">
# <b>Комментарий студента 🎓:</b>
#
#
# </div>
# </div>
#
# <hr>
#
# Также я прошу тебя **не менять, не передвигать и не удалять мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# <hr>
#
# **По проекту:** Молодец, была проделана большая работа! Есть [моменты, которые нужно исправить](#result-1) - их я подробно отразил в своих комментариях. Если появятся вопросы, с радостью на них отвечу (также вопросы можно задавать преподавателю по проектам в слаке). Верю, что ты со всем справишься, и с нетерпением жду проект на повторную проверку!
#
# **По проекту V.2:** Ударно поработали, молодец! Почти все замечания были отработаны! Осталось ещё [немного постараться](#result-2), верю в тебя и жду проект на проверку 😉
#
# **По проекту V.3:** В итоге получилась очень сильная работа! Видно, что вложено много труда, осознанность присутствует в каждой фразе и в каждом действии! Очень редко встречаются подобные проекты, которые хочется снова перечитать и ставить в пример остальным студентам! Надеюсь, что ты продолжишь использовать такой подход и после перенесёшь в работу, где, я уверен, у тебя всё получится! ⭐⭐⭐⭐⭐
#
# **P.s.** Такой комментарий я пишу крайне редко, если работа в итоге действительно произвела на меня впечатление
#
# **P.s.s.** Проект принят, поздравляю! Надеюсь, что смог помочь тебе сделать ещё один шаг на пути обучения, в котором желаю тебе удачи и больших успехов! Оставил ещё пару комментариев в работе 😎
#
#
# </div>

# %% [markdown]
# <h1>Содержание (кликабельное):</h1>
#
# <a href='#h0'>1. Название прокта</a><br>
# <a href='#h1'>2. Описание проекта, импорт библиотек</a><br>
# <a href='#h2'>3. Ознакомление с данными</a><br>
# <a href='#h3'>4. Подготовим данные</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h4'>4.1 Изменим название колонок</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h5'>4.2. Преобразуем данные в нужные типы</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h6'>4.3 Подсчитаем кол-во пропусков</a><br>
# <a href='#h7'>5. Исследовательский анализ данных</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h9'>5.1 Платформы с наибольшими суммарными продажами и распределение по годам</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h10'>5.2 За какой характерный срок появляются новые и исчезают старые платформы?</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#h11'>5.3 Какие платформы лидируют по продажам, растут или падают?</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h12'>5.4 Несколько потенциально прибыльных платформ</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h13'>5.5 Возьмеи данные за актуальный период</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h16'>5.6 График «ящик с усами</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h17'>5.7 Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h20'>5.8 Посмотрите на общее распределение игр по жанрам</a><br>
# <a href='#h21'>6. Составьте портрет пользователя каждого региона</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h22'>6.1 Самые популярные платформы (топ-5).</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h23'>6.2 Самые популярные жанры (топ-5)</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h24'>6.3 Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a><br>
# <a href='#h25'>7 Проверьте гипотезы</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h26'>7.1 Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a><br>
# &nbsp;&nbsp;&nbsp;<a href='#h27'>7.2 Средние пользовательские рейтинги жанров Action  и Sports разные</a><br>
# <a href='#h28'>8 Общий вывод</a><br>

# %% [markdown]
# <a id='h1'></a>
# ### Изучим общую информацию.

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.

# %% [markdown]
# **Описание данных**<br>
# Name — название игры<br>
# Platform — платформа<br>
# Year_of_Release — год выпуска<br>
# Genre — жанр игры<br>
# NA_sales — продажи в Северной Америке (миллионы долларов)<br>
# EU_sales — продажи в Европе (миллионы долларов)<br>
# JP_sales — продажи в Японии (миллионы долларов)<br>
# Other_sales — продажи в других странах (миллионы долларов)<br>
# Critic_Score — оценка критиков (максимум 100)<br>
# User_Score — оценка пользователей (максимум 10)<br>
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.<br>
# Данные за 2016 год могут быть неполными.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id='h2'><a>
# ### Ознакомление с данными

# %%
data = pd.read_csv('/datasets/games.csv')
pd.set_option('display.max_columns', None)
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
data.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# **Вывод**
#
# Столбцы Name и Genre имеют по 2 пропуска эти не ячейки можно исключить из анализа, так как их очень очень мало от общего кол-ва и они не будут влиять на результат.
# Столбцы Critic_Score и User_Score и Rating, требуют более делального рассмотрения для решиния по обработке пропусков.
# Необходимо поменять тип данных в столбцах Year_of_Release и User_Score ( посмотреть почему тип оbject).
# Для более удобной работы с базой поменять регистр некоторых столбцов и данных в них.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично, в выводе отражены все основные моменты после загрузки и первичного осмотра данных 😎
#
# </div>
# </div>

# %% [markdown]
# <a id='h3'><a>
# ### Подготовим данные

# %% [markdown]
# <a id='h4'><a>
# #### Изменим название колонок

# %%
data.columns.tolist()
# Out:
# ['Name',
#  'Platform',
#  'Year_of_Release',
#  'Genre',
#  'NA_sales',
#  'EU_sales',
#  'JP_sales',
#  'Other_sales',
#  'Critic_Score',
#  'User_Score',
#  'Rating']

# %%
data.columns = data.columns.str.lower()

# %%
data.columns.tolist()
# Out:
# ['name',
#  'platform',
#  'year_of_release',
#  'genre',
#  'na_sales',
#  'eu_sales',
#  'jp_sales',
#  'other_sales',
#  'critic_score',
#  'user_score',
#  'rating']

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b>
#
# Отлично, привели названия признаков (столбцов) в порядок 👍
#
# </div>
# </div>

# %% [markdown]
# <a id='h5'><a>
# #### Преобразуем данные в нужные типы

# %% [markdown]
# Рассмотрим информации о датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# взглянем на сам датасет

# %%
data.head(5)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Проверим есть ли дубликаты, если есть избавимя от них.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *Дубликатов нет*

# %% [markdown]
# <a id='h6'><a>
# **Подсчитаем кол-во пропусков**

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Очень сложно будет определить,что это за игры просто уберем их.

# %%
data = data.dropna(subset=['name']) 
print(data.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         6699
# rating             6764
# dtype: int64

# %%
data['name'].unique().tolist()
# Out:
# ['Wii Sports',
#  'Super Mario Bros.',
#  'Mario Kart Wii',
#  'Wii Sports Resort',
#  'Pokemon Red/Pokemon Blue',
#  'Tetris',
#  'New Super Mario Bros.',
#  'Wii Play',
#  'New Super Mario Bros. Wii',
#  'Duck Hunt',
#  'Nintendogs',
#  'Mario Kart DS',
#  'Pokemon Gold/Pokemon Silver',
#  'Wii Fit',
#  'Kinect Adventures!',
#  'Wii Fit Plus',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: San Andreas',
#  'Super Mario World',
#  'Brain Age: Train Your Brain in Minutes a Day',
#  'Pokemon Diamond/Pokemon Pearl',
#  'Super Mario Land',
#  'Super Mario Bros. 3',
#  'Grand Theft Auto: Vice City',
#  'Pokemon Ruby/Pokemon Sapphire',
#  'Brain Age 2: More Training in Minutes a Day',
#  'Pokemon Black/Pokemon White',
#  'Gran Turismo 3: A-Spec',
#  'Call of Duty: Modern Warfare 3',
#  'Pokémon Yellow: Special Pikachu Edition',
#  'Call of Duty: Black Ops 3',
#  'Call of Duty: Black Ops',
#  'Pokemon X/Pokemon Y',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Modern Warfare 2',
# ...

# %%
len(data['name'].unique())
# Out:
# 11559

# %%
data['name'] = data['name'].str.upper()

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <s>Комментарий ревьюера ⚠️:</b>
#
# Предупреждения можно отключить, добавив в начале проекта:
#
# ```
# import warnings
# warnings.filterwarnings("ignore")
# ```
#
# </div>
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-block alert-info">
# <b>добавил в начало:</b>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %%
len(data['name'].unique())
# Out:
# 11559

# %%
data['name']
# Out:
# 0                           WII SPORTS
# 1                    SUPER MARIO BROS.
# 2                       MARIO KART WII
# 3                    WII SPORTS RESORT
# 4             POKEMON RED/POKEMON BLUE
#                      ...
# 16710    SAMURAI WARRIORS: SANADA MARU
# 16711                 LMA MANAGER 2007
# 16712          HAITAKA NO PSYCHEDELICA
# 16713                 SPIRITS & SPELLS
# 16714              WINNING POST 8 2016
# Name: name, Length: 16713, dtype: object

# %% [markdown]
# Возможно есть, но они не явные

# %%
data.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
data['platform'] = data['platform'].str.upper()

# %%
data['platform'].unique()
# Out:
# array(['WII', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XONE',
#        'WIIU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# data.info()

# %% [markdown]
# **год релиза игры может быть любой, поэтому удалим пропуски

# %%
# data['year_of_release'] = data['year_of_release'].fillna(-1)
data = data.dropna(subset=['year_of_release']) 
data['year_of_release'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <s>Комментарий ревьюера ⚠️:</b>
#
# В данном случае рекомендую сразу удалять такую малую долю пропусков для экономии времени
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# исправил
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %%
data['year_of_release'] = data['year_of_release'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       9839 non-null   object
#  10  rating           9768 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
data['genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %%
data['rating'] = data['rating'].str.upper()

# %% [markdown]
# **Колонки с рейтингами трогать или заполнять не будем**

# %%
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data[data['user_score'] == 'tbd']
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     ZUMBA FITNESS      WII             2010      Sports
# 301    NAMCO MUSEUM: 50TH ANNIVERSARY      PS2             2005        Misc
# 520                   ZUMBA FITNESS 2      WII             2011      Sports
# 645                      UDRAW STUDIO      WII             2010        Misc
# 718                   JUST DANCE KIDS      WII             2010        Misc
# ...                               ...      ...              ...         ...
# 16695                 PLANET MONSTERS      GBA             2001      Action
# 16697                BUST-A-MOVE 3000       GC             2003      Puzzle
# 16698                MEGA BRAIN BOOST       DS             2008      Puzzle
# 16704                        PLUSHEES       DS             2008  Simulation
# 16706   MEN IN BLACK II: ALIEN ESCAPE       GC             2003     Shooter
#
# ...

# %% [markdown]
# В общем, как говорят в Америке, TBD (to be determined = будет определено).

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# Возможно NAN это отсутсвие отзывов, а тба слишком малое близкое к нолю кол-во,

# %% [markdown]
# Так NAN и TBD это одно и тоже.
# Заменим их одним значением.

# %%
data['user_score'] = data['user_score'].fillna(-1)

# %%
data['user_score'] = data['user_score'].replace('tbd', -1)

# %%
data['user_score'] = data['user_score'].astype('float')

# %%
data['user_score'].unique()
# Out:
# array([ 8. , -1. ,  8.3,  8.5,  6.6,  8.4,  8.6,  7.7,  6.3,  7.4,  8.2,
#         9. ,  7.9,  8.1,  8.7,  7.1,  3.4,  5.3,  4.8,  3.2,  8.9,  6.4,
#         7.8,  7.5,  2.6,  7.2,  9.2,  7. ,  7.3,  4.3,  7.6,  5.7,  5. ,
#         9.1,  6.5,  8.8,  6.9,  9.4,  6.8,  6.1,  6.7,  5.4,  4. ,  4.9,
#         4.5,  9.3,  6.2,  4.2,  6. ,  3.7,  4.1,  5.8,  5.6,  5.5,  4.4,
#         4.6,  5.9,  3.9,  3.1,  2.9,  5.2,  3.3,  4.7,  5.1,  3.5,  2.5,
#         1.9,  3. ,  2.7,  2.2,  2. ,  9.5,  2.1,  3.6,  2.8,  1.8,  3.8,
#         0. ,  1.6,  9.6,  2.4,  1.7,  1.1,  0.3,  1.5,  0.7,  1.2,  2.3,
#         0.5,  1.3,  0.2,  0.6,  1.4,  0.9,  1. ,  9.7])

# %%
 data['genre'] = data['genre'].fillna('-')

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score            0
# rating             6676
# dtype: int64

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера ❌:</b>
#
# Если оставим пропуски в rating без предобработки, то игры без рейтинга оказываются полностью исключенными из анализа вопроса влияния рейтинга ESRB в регионах, но продажи именно этих игр могут указать на ключевое различие в регионах (небольшой спойлер 😉)
# </div>
# </div>

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Заполним пропуски в столбце рейтинг каким нибудь текстом.

# %%
data['rating'] = data['rating'].fillna('not entered')

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score            0
# rating                0
# dtype: int64

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h7'><a>
# #### Посчитайте суммарные продажи во всех регионах

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b>
#
# Согласен 💪 Здесь также можно использовать `data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)`
#
# </div>
# </div>

# %% [markdown]
# **Вывод:**
# В данном раздели мы избавились от пропусков в ячейках (year_of_release, genre) запонили значениями пропуски (rating,user_score) и поменяли формат данных в ячейках(year_of_release, user_score) и помегняли региств в ячейках столбца platform на верхний

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h7'><a>
# ### Исследовательский анализ данных

# %%
data.groupby('year_of_release')['total_sales'].count().plot(x='year_of_release', y='total_sales', figsize=(16,10), xlim=(1980,2017))
plt.title('Распределение по годам релиза', fontweight='bold', fontsize='16', horizontalalignment='center')
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.show()

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера ❌:</b>
#
# Здесь мы смотрим не продажи (sum), а количество выпущенных игр (count)
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Исправил
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# С развитием интернет технологий увеличивалось и кол-во игр. <br>
# Возьмем актуальный период последние 3 года

# %% [markdown]
# <a id='h8'><a>
# **Рассмотрим данные по платформам платформам**

# %%
sales_platform = pd.pivot_table(data, index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')

# %%
sales_platform.tail(5)
# Out:
# platform         2600  3DO    3DS  DC     DS  GB  GBA  GC  GEN  GG  N64  NES  \
# year_of_release
# 2012              NaN  NaN  51.36 NaN  11.01 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2013              NaN  NaN  56.57 NaN   1.54 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2014              NaN  NaN  43.76 NaN    NaN NaN  NaN NaN  NaN NaN  NaN  NaN
# 2015              NaN  NaN  27.78 NaN    NaN NaN  NaN NaN  NaN NaN  NaN  NaN
# 2016              NaN  NaN  15.14 NaN    NaN NaN  NaN NaN  NaN NaN  NaN  NaN
#
# platform         NG     PC  PCFX  PS  PS2     PS3     PS4   PSP    PSV  SAT  \
# year_of_release
# 2012            NaN  23.22   NaN NaN  NaN  107.36     NaN  7.69  16.19  NaN
# 2013            NaN  12.38   NaN NaN  NaN  113.25   25.99  3.14  10.59  NaN
# 2014            NaN  13.28   NaN NaN  NaN   47.76  100.00  0.24  11.90  NaN
# 2015            NaN   8.52   NaN NaN  NaN   16.82  118.90  0.12   6.25  NaN
# 2016            NaN   5.25   NaN NaN  NaN    3.60   69.25   NaN   4.25  NaN
#
# ...

# %%
sales_platform.plot(figsize=(20,10))
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.title('Продажи по платформам', fontsize=15, color='blue')
plt.show()

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# **Новый график ниже**

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера V.2 ❌:</b>
#
# Если на графике много информации, то можно разбить его на два или три графика поменьше. Стиль линий предлагаю задать так (эту строку нужно убрать ```plt.style.use('ggplot;')``` для корректного отображения), например:
# ```
# styles = ['o-'] * 10 + ['s-'] * 10 + ['^-'] * 10
# sales_platform.plot(style=styles, figsize=(15, 10), grid=True);
# ```
# Можно также задать палитру цветов, которую потом присваем параметру ```color```(как ты верно заметил), например:
#
# ```
# colors = [здесь задаёшь цвета] - палитра
# sales_platform.plot(figsize=(15,7), stacked=True, color=colors) - график
# ```
# </div>
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# И небольшой подарок от меня в виде полезных ссылок, которые могут пригодиться в будущих исследованиях 😉 (от начального до продвинутого уровня (есть и на английском)):
#
# * https://extremepresentation.typepad.com/.a/6a00d8341bfd2e53ef0111683a7591970c-pi - Схема для выбора визуализации в зависимости от задач;
# * https://habr.com/ru/post/521894/ - Формат таблиц в pandas с помощью style. В том числе цветовое выделение;
# * https://habr.com/ru/post/468295 - 50 оттенков matplotlib. С кодом и примерами;
# * https://www.litres.ru/aleksandr-bogachev/grafiki-kotorye-ubezhdaut-vseh/ - Книга о том, как строить графики, от подготовки данных до конкретных подписей;
# * https://datavizproject.com/ - Сайт, подробно представлюящий практически все типы визуализаций;
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html - Более сложные примеры по использованию style;
# * https://habr.com/ru/post/502958 - Шпаргалка по plotly. Набор опций с подробным описанием и примерами. С чего начать погружение в мир интерактивности и чем продолжить.
#
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Спасибо
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Всегда пожалуйста ⭐
#
# </div>
# </div>

# %%
styles = ['o-'] * 10 + ['s-'] * 10 + ['^-'] * 10 + ['v-'] * 10
sales_platform.plot(style=styles, figsize=(23,15),grid=True)
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.title('Продажи по платформам', fontsize=15, color='blue')
plt.show()

# %%
total_sales_platform = data.groupby('platform')['total_sales'].sum().to_frame('total_sales').sort_values(by='total_sales', ascending=False)

# %%
total_sales_platform
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# WII            891.18
# DS             802.78
# PS             727.58
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81
# PC             255.76
# GB             254.43
# XB             251.57
# NES            251.05
# N64            218.01
# SNES           200.04
# GC             196.73
# XONE           159.32
# 2600            86.48
# WIIU            82.19
# PSV             53.81
# SAT             33.59
# GEN             28.35
# DC              15.95
# SCD              1.86
# NG               1.44
# WS               1.42
# TG16             0.16
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %% [markdown]
# **Вывод**
#
# Самой популярной платформой является Ps2, Дальше уже идут более современный Ps3 и х360, на последних места самый ранние игровые консоли.

# %% [markdown]
# <a id='h9'><a>
# #### Платформы с наибольшими суммарными продажами и распределение по годам.

# %% [markdown]
# Возьмем первые 5

# %%
top_sales_platform = total_sales_platform.head(5)

# %%
top_sales_platform
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# WII            891.18
# DS             802.78

# %%
top_sales_platform = data.query('platform in ("PS2","X360","PS3","WII","DS")')

# %%
pd.pivot_table(top_sales_platform, index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(16,10), xlim=(2000,2016), colormap = 'Set1')
plt.title('Продажи по самым популярным платформам', fontsize=15, color='blue')
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.show()

# %% [markdown]
# Срок жизни игровых платформ:
#
# PS2 - 12 лет
#
# DS - 10 лет
#
# WII - 11 лет
#
# PS3 - 11 лет
#
# x360 - 12 лет
#
# В среднем у популярных платформ примерно чуть больше 10 лет.

# %% [markdown]
# <a id='h10'><a>
# #### За какой характерный срок появляются новые и исчезают старые платформы?

# %%
sale_time_platform = data.groupby(['platform', 'year_of_release']).agg({'total_sales':'sum'}).reset_index()

# %%
sale_time_platform
# Out:
#     platform  year_of_release  total_sales
# 0       2600             1980        11.38
# 1       2600             1981        35.68
# 2       2600             1982        28.88
# 3       2600             1983         5.84
# 4       2600             1984         0.27
# ..       ...              ...          ...
# 233       XB             2008         0.18
# 234     XONE             2013        18.96
# 235     XONE             2014        54.07
# 236     XONE             2015        60.14
# 237     XONE             2016        26.15
#
# [238 rows x 3 columns]

# %%
sale_time_platform['platform'].value_counts()
# Out:
# PC      26
# GB      13
# PS2     12
# PSP     12
# X360    12
# NES     12
# PS3     11
# DS      11
# WII     11
# SNES    10
# PS      10
# 2600    10
# XB       9
# GBA      8
# N64      7
# GC       7
# DC       7
# 3DS      6
# PSV      6
# SAT      6
# WIIU     5
# GEN      5
# NG       4
# PS4      4
# XONE     4
# WS       3
# SCD      2
# 3DO      2
# GG       1
# TG16     1
# PCFX     1
# Name: platform, dtype: int64

# %%
sale_time_platform['platform'].value_counts().mean()
# Out:
# 7.67741935483871

# %% [markdown]
# **Время за которое появляются новые и исчезают старые платформы примено 8 лет**

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h11'><a>
# #### Возьмеи данные за актуальный период.

# %% [markdown]
# Примем актуальрный период с 2013 - по 2016 год

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# #actual_data = data.query('year_of_release >= 2007')
#
# #actual_data.head(5)

# %%
actual_data = data.query('year_of_release >= 2013')
actual_data.head(5)
# Out:
#                          name platform  year_of_release         genre  \
# 16         GRAND THEFT AUTO V      PS3             2013        Action
# 23         GRAND THEFT AUTO V     X360             2013        Action
# 31  CALL OF DUTY: BLACK OPS 3      PS4             2015       Shooter
# 33        POKEMON X/POKEMON Y      3DS             2013  Role-Playing
# 42         GRAND THEFT AUTO V      PS4             2014        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38           NaN        -1.0
# 33      5.28      4.19      4.35         0.78           NaN        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#          rating  total_sales
# 16            M        21.05
# 23            M        16.27
# ...

# %%
pd.pivot_table(actual_data, index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(16,10), colormap = 'gist_ncar')
plt.grid(True)
plt.title('Продажи по платформам за актуальный период', fontsize=17, color='blue')
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.show()

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <b>Комментарий ревьюера V.3 ⚠️:</b>
#
# Белый цвет у XOne очень тяжело рассмоть на графике (у меня вышло, поэтому комментарий жёлтый)
#
# </div>
# </div>

# %% [markdown]
# <a id='h12'><a>
# #### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ

# %%
actual_sale_time_platform = actual_data.groupby(['platform', 'year_of_release']).agg({'total_sales':'sum'}).reset_index()

# %%
total_actual_sale_time_platform = actual_data.groupby('platform')['total_sales'].sum().to_frame('total_sales').sort_values(by='total_sales', ascending=False)

# %%
total_actual_sale_time_platform
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            181.43
# XONE           159.32
# 3DS            143.25
# X360           136.80
# WIIU            64.63
# PC              39.43
# PSV             32.99
# WII             13.66
# PSP              3.50
# DS               1.54

# %% [markdown]
# По сравнению с общими показателями данные за последние 3 год другие.
# Тут больше всего проданно игры у новенькой ps4, уже не новая ps3 на втором месте, а новый xbox, отстает от ps прошлого покаления. Хуже всего продаются игыр на портативные приставки

# %% [markdown]
# <a id='h13'><a>
# #### Несколько потенциально прибыльных платформ

# %%
total_actual_sale_time_platform.median()
# Out:
# total_sales    64.63
# dtype: float64

# %% [markdown]
# Возьмем компании больше медианы.

# %%
top_actual_platform = total_actual_sale_time_platform.head(10)

# %% [markdown]
# По прибыли можно выделить следующие платформы.

# %%
top_actual_platform
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            181.43
# XONE           159.32
# 3DS            143.25
# X360           136.80
# WIIU            64.63
# PC              39.43
# PSV             32.99
# WII             13.66
# PSP              3.50

# %% [markdown]
# Из это списка выберем самые потенциально прибыльные.

# %%
top_act_platform = data.query('platform in ("PS4","PS3","XONE","3DS","X360","WIIU","PC","PSV","WII","PSP")')

# %%
pd.pivot_table(top_act_platform, index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(16,10), xlim=(2000,2016), colormap='hsv')
plt.title('Продажи по самым популярным платформам', fontsize=15, color='blue')
plt.xlabel('Года',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.show()

# %%
sale_time_act_platform = top_act_platform.groupby(['platform', 'year_of_release']).agg({'total_sales':'sum'}).reset_index()

# %%
sale_time_act_platform['platform'].value_counts()
# Out:
# PC      26
# X360    12
# PSP     12
# WII     11
# PS3     11
# PSV      6
# 3DS      6
# WIIU     5
# XONE     4
# PS4      4
# Name: platform, dtype: int64

# %% [markdown]
# Так как платформы живут в среднем 8 лет, примем за актуальные платформы возрастом меньше 6 лет, что бы они хотябы еще 2-3 года были актуальны и приносили прибыль, а также PC хоть он и очень старый, но давно перешагнул среднее время жизни за 8 лет и спроси на игры довольно стабилен.

# %%
df_act_plat = ['PC','WIIU','PS4','XONE', '3DS']

# %% [markdown]
# Список потенциально прибыльных платформ 'PC', 'WIIU' ,'PS4', 'XONE', '3DS'

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера V.2 ❌:</b>
#
# Здесь также можно взять 3DS - новая платформа в своей линейке, входит в ТОП-3 по продажам в 2016 году
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Добавил в список 3DS
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# **По графику видно, что графики по продажам падают**
#
# Тут можно предположить,что на продажи следующие факторы:
# Предоставлять много игры по подписке( пример PS PLUS), следовательно теряется смысл покупать игры отдельно.
#
# Развитие Пиратства, взломщики игр не сидят сложа руки.
#
# Появление игр с дополнениями(DLC), вместо выхода полноценной новой игры.

# %% [markdown]
# <a id='h16'></a>
# #### график «ящик с усами»

# %% [markdown]
# <div class="alert alert-info">
# Хорошо во всех вопросах ниже изменю data actual_data.
# Если я не правильно понял то составь пожалуйста список где мы используем изначальный датафрейм (data), где за актуальный период actual_data.
# Путому что я не понимаю зачем мне в портрете пользователей использовать actual_data.
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Ты всё верно сделал. Мы используем актуальный период, чтобы не захватить отжившие тренды и сконцентрироваться на новых платформах, актуальных популярных жанрах и возрастных рейтингах. Так мы понимаем, во что вкладываться в текущей ситуации в каждом из регионов - это важно для бизнеса, который является заказчиком
#
# </div>
# </div>

# %%
data.boxplot('total_sales', figsize=(8,6)).set_ylim(0, 2)
plt.ylabel('Общая выручка')
plt.show()

# %% [markdown]
# Медиана на уровна 0.2 мил. среднее 1.2 мил.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера ❌:</b>
#
# Необходимо построить график в разбивке по платформе (на одном графике несколько ящиков с усами для каждой платформы), а не по всем продажам в целом
#
# </div>
# </div>

# %% [markdown]
# По наиболее актульным на конец 2016 года платформам.

# %%
pop_platforms = actual_data[actual_data['platform'].isin(['PC','WIIU','PS4','XONE','3DS'])] 
sns.boxplot(x='platform', y='total_sales', data=pop_platforms)
plt.title('График с усами по самым популярным платформам', fontsize=15, color='blue')
plt.xlabel('Платформы',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.ylim((0,2))
plt.figure(figsize=(12,15));

# %% [markdown]
# **Вывод**

# %% [markdown]
# Медиана по топовым платформам примерно 0.2 - 0.25 млн.
# Верхняя граница предела, за которыми уже определяются аномалии, у двух платформ - PS4 и XONE - на уровне 1,6 млн долларов.
# У Wiiu 1.4 млн. У пк все хуже, но и находится на рынке он больше остальных, денег на рекламы продажи игр тратится меньше.

# %% [markdown]
# <a id='h17'><a>
# #### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# Возьмем XONE она была второй рейтинге за актуальный и общий период

# %%
data_XONE = actual_data.query('platform == "XONE"')
data_XONE.head(10)
# Out:
#                                name platform  year_of_release         genre  \
# 99        CALL OF DUTY: BLACK OPS 3     XONE             2015       Shooter
# 165              GRAND THEFT AUTO V     XONE             2014        Action
# 179  CALL OF DUTY: ADVANCED WARFARE     XONE             2014       Shooter
# 242               HALO 5: GUARDIANS     XONE             2015       Shooter
# 270                       FALLOUT 4     XONE             2015  Role-Playing
# 342    STAR WARS BATTLEFRONT (2015)     XONE             2015       Shooter
# 373         ASSASSIN'S CREED: UNITY     XONE             2014        Action
# 398                         DESTINY     XONE             2014       Shooter
# 413  GEARS OF WAR: ULTIMATE EDITION     XONE             2015       Shooter
# 417                         FIFA 16     XONE             2015        Sports
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
data_XONE.describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       247.000000  247.000000  247.000000  247.000000   247.000000
# mean       2014.951417    0.377004    0.208866    0.001377     0.057773
# std           0.952995    0.630618    0.365306    0.005153     0.094221
# min        2013.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2014.000000    0.030000    0.020000    0.000000     0.010000
# 50%        2015.000000    0.120000    0.070000    0.000000     0.020000
# 75%        2016.000000    0.385000    0.220000    0.000000     0.060000
# max        2016.000000    4.590000    2.190000    0.040000     0.680000
#
#        critic_score  user_score  total_sales
# count    169.000000  247.000000   247.000000
# mean      73.325444    4.542105     0.645020
# std       12.953465    3.523823     1.036139
# min       20.000000   -1.000000     0.010000
# 25%       66.000000   -1.000000     0.060000
# 50%       76.000000    6.000000     0.220000
# ...

# %%
data_XONE = data_XONE.query('user_score >= 0')

# %%
data_XONE.describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       182.000000  182.000000  182.000000  182.000000   182.000000
# mean       2014.934066    0.431923    0.238132    0.001593     0.066044
# std           0.989472    0.620657    0.377369    0.005679     0.092520
# min        2013.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2014.000000    0.040000    0.020000    0.000000     0.010000
# 50%        2015.000000    0.170000    0.090000    0.000000     0.030000
# 75%        2016.000000    0.557500    0.275000    0.000000     0.090000
# max        2016.000000    3.220000    2.190000    0.040000     0.480000
#
#        critic_score  user_score  total_sales
# count    165.000000  182.000000   182.000000
# mean      73.618182    6.521429     0.737692
# std       12.883849    1.380941     1.018062
# min       20.000000    1.600000     0.010000
# 25%       67.000000    5.800000     0.082500
# 50%       76.000000    6.800000     0.300000
# ...

# %%
XONE_2 = data_XONE[['total_sales', 'critic_score', 'user_score']]
XONE_2
# Out:
#        total_sales  critic_score  user_score
# 165           5.47          97.0         7.9
# 179           5.26          81.0         5.4
# 242           4.49          84.0         6.4
# 270           4.22          88.0         6.2
# 373           3.50          72.0         4.1
# ...            ...           ...         ...
# 16544         0.01           NaN         6.8
# 16597         0.01          65.0         6.0
# 16630         0.01          63.0         8.2
# 16643         0.01           NaN         6.6
# 16660         0.01          74.0         6.7
#
# [182 rows x 3 columns]

# %% [markdown]
# Диаграмма рассеивания продаж и оценки критиков

# %%
data_XONE.plot(kind='scatter', x='critic_score', y='total_sales', figsize=(15,7), grid=True, alpha=0.7, ec='black')
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='total_sales'>

# %% [markdown]
# **С увеличением оценки критиков, увеличивается и выручка**

# %% [markdown]
# Диаграмма рассеивания продаж и оценки пользователей

# %%
data_XONE.plot(kind='scatter', x='user_score', y='total_sales', figsize=(15,7), grid=True, alpha=0.7, ec='black')
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %% [markdown]
# **С увеличением оценки пользователей, увеличивается и выручка**

# %% [markdown]
# **построим матрицу кореляции**

# %%
XONE_2.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.410422   -0.068925
# critic_score     0.410422      1.000000    0.472462
# user_score      -0.068925      0.472462    1.000000

# %% [markdown]
# <a id='h18'></a>
# **Вывод**
#
# Существует слабая зависимость,ее практически нету между оценкой критоков и оценкой пользователей
#
# Зависимости продаж от оценки нет.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <s>Комментарий ревьюера ⚠️:</b>
#
# Корреляция меньше 0.5 уже говорит о слабой взаимосвязи (даже скорее об её отсутствии)
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Подправил вывод
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %%
top_actual_platform = top_actual_platform.reset_index()

# %%
for plat in top_actual_platform['platform']:
    data_platform = actual_data[(actual_data['platform'] == plat) & (actual_data['user_score'] > 0)]
    plat_cor = data_platform[['total_sales' ,'critic_score', 'user_score']]
    print(plat)
    print(plat_cor.corr())
    print(" ")
# Out:
# PS4
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.405895   -0.031957
# critic_score     0.405895      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000
#
# PS3
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.333807    0.002394
# critic_score     0.333807      1.000000    0.599920
# user_score       0.002394      0.599920    1.000000
#
# XONE
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.410422   -0.068925
# critic_score     0.410422      1.000000    0.472462
# user_score      -0.068925      0.472462    1.000000
#
# 3DS
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.339235    0.241504
# critic_score     0.339235      1.000000    0.769536
# user_score       0.241504      0.769536    1.000000
#
# X360
#               total_sales  critic_score  user_score
# ...

# %% [markdown]
# <a id='h19'></a>
# **Вывод:**

# %% [markdown]
# В целом ситуация по поулярным платформам сохраняется:
#
# Существует зависимость между оценкой критоков и оценкой пользователей
#
# Зависимось продаж от оценок не вилика, но отзывы критиков важнее, отзывов пользователей
#
# Больше всего это наблюдается у не старых платформ, а у новых платформ ситуация с отзывами чуть другая, наверное еще не успели собрать достаточно.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h20'></a>
# #### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
genre_pivot = actual_data.groupby('genre').agg({'name': 'count', 'total_sales': 'sum'}).sort_values(by='total_sales')

# %%
genre_pivot
# Out:
#               name  total_sales
# genre
# Puzzle          17         3.17
# Strategy        56        10.08
# Simulation      62        21.76
# Adventure      245        23.64
# Fighting        80        35.31
# Racing          85        39.89
# Platform        74        42.63
# Misc           155        62.82
# Role-Playing   292       145.89
# Sports         214       150.65
# Shooter        187       232.98
# Action         766       321.87

# %%
genre_pivot['name'].plot(kind='bar', figsize=(15,5), ec='black', width=0.2, position=0)
genre_pivot['total_sales'].plot(kind='bar', figsize=(15,5), ec='black', width=0.2, color='orange', position=1)
plt.title('Распределение игр по жанрам',fontsize=15, color='blue')
plt.xlabel('Жанры',fontsize=15, color='blue')
plt.ylabel('Продажи млн.',fontsize=15, color='blue')
plt.legend(['Количество проданных игр', 'Общая сумма продаж'])
plt.show()

# %% [markdown]
# Самый припыбыльный и популярный жанр Action, второй в рейтинге по продажам и сумме Sport. Игры с жанорм Adventure и имеею среднее кол-во продаж, но маленькую прибыли, наверное это связанной с ценой за копию. Худшие по продажам и прибыли игры жанра Puzzle. Shooter приносит не плохой доход за игру. Лучший в показателе доход дел на кол-во игр.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
# <s>Комментарий ревьюера ❌:</b>
#
# Мы правильно выяснили, какие жанры являются популярными из-за текущей игровой моды (оценили общие суммарные продажи). Чтобы понять полную картину, нам необходимо также рассмотреть средние/медианные продажи по жанрам (это стандартная практика при анализе продаж), чтобы понять, какие из них стабильно приносят прибыль. С учётом этого, нужно дополнить исследование, а вывод ниже необходимо обновить
#
# </div>
# </div>

# %% [markdown]
# Построи таблицу и график распрелеления средних продаж по жанрам

# %%
data_sales_genre_mean = actual_data.groupby(['genre']).agg({'total_sales':'mean'}).reset_index()
data_sales_genre_mean = data_sales_genre_mean.rename(columns={"total_sales": "mean_sales"})
data_sales_genre_mean = data_sales_genre_mean.sort_values(by='mean_sales', ascending=False)
plt.figure(figsize=(22, 12))
plt.bar(data_sales_genre_mean['genre'], data_sales_genre_mean['mean_sales']);
plt.title('Pаспределение Жанров по средним продажам', fontsize=15, color='blue')
plt.xlabel('Жанры',fontsize=15, color='blue')
plt.ylabel('Cр.прод',fontsize=15, color='blue')
plt.legend(['Cр.прод'])
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-warning">
# <s>Комментарий ревьюера V.2 ⚠️:</b>
#
# Я бы рекомендовал отсортировать значения и использовать столбчатый график для наглядности
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Подправил
# </div>

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %%
data_sales_genre_mean.sort_values(by='mean_sales', ascending=False)
# Out:
#            genre  mean_sales
# 8        Shooter    1.245882
# 10        Sports    0.703972
# 4       Platform    0.576081
# 7   Role-Playing    0.499623
# 6         Racing    0.469294
# 2       Fighting    0.441375
# 0         Action    0.420196
# 3           Misc    0.405290
# 9     Simulation    0.350968
# 5         Puzzle    0.186471
# 11      Strategy    0.180000
# 1      Adventure    0.096490

# %% [markdown]
# Посомтрим сколько в среднем приносит продажа игр

# %%
data_sales_genre_mean['mean_sales'].mean()
# Out:
# 0.4646368394234556

# %% [markdown]
#  **Вывод:**
# Самый припыбыльный и популярный жанр Action, второе и третье место в рейтинге по продажам делят Shooter и Role-playing. Игры с жанорм Adventure и имеею среднее кол-во проданных игры, но маленькую прибыли, наверное это связанной с ценой за копию. Худшие по продажам и прибыли игры жанра Puzzle.
#
# А в среднем одна игра жанра Shooter приносит почти в 3 раза больше прибыли,а игра жанра sports в 1.5 больше жанра самого полярного жанра Action, который занимает средние показатели по продажам за игру. Ну Жанр худщий по прибыли за игру Adventure можно сказать, что не приносит денег.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h21'><a/>
# ### Составьте портрет пользователя каждого региона

# %% [markdown]
# <a id='h22'></a>
# #### Самые популярные платформы (топ-5).

# %%
users_na = actual_data.groupby(['platform']).agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5)

users_eu = actual_data.groupby(['platform']).agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5)

users_jp = actual_data.groupby(['platform']).agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5)

# %%
users_na.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
users_eu.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
users_jp.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='platform'>

# %% [markdown]
# В Северной Америке популярны приставки PS4 и XONE. Немного отстает x360. Топ-4 PS3 и топ-5 3DS соответственно.
#
# В Европе cупер популярна Ps4, на втором месте предыдущая версия приставки ps3. с почти одинаковой популярностью X360, XONE, а 3DS топ-5.
#
# В Японии популярен 3DS, дальше PS3 и PSV. топ-4 и топ-5 PS4 и WIIU соответсвенно. На Азиатском рынке наблюдаются другие тенденции.

# %% [markdown]
# <a id='h23'></a>
# #### Самые популярные жанры (топ-5).

# %%
genre_na = actual_data.groupby(['genre']).agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5)

genre_eu = actual_data.groupby(['genre']).agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5)

genre_jp = actual_data.groupby(['genre']).agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5)

# %%
print(genre_na)
print(genre_eu)
print(genre_jp)
# Out:
#               na_sales
# genre
# Action          126.05
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.49
#               eu_sales
# genre
# Action          118.13
# Shooter          87.86
# Sports           60.52
# Role-Playing     36.97
# Racing           20.19
#               jp_sales
# genre
# Role-Playing     51.04
# Action           40.49
# Misc              9.20
# Fighting          7.65
# Shooter           6.61

# %%
genre_na.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
genre_eu.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
genre_jp.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='genre'>

# %% [markdown]
# В Северной Америке самые популярные игры жанра Action и Shooter, дальше Sports,Role-Playing и Misc
# В Европе самые популярные игры жанра Action и Shooter,дальше Sports, Role-Playing и Racing
# В Японии с большим отрывом популярен Role-Playing, примерно на равных показателях Action, и топ 3-5 Sports, fighting, Misc. Ну опять же особенности Азиатского рынка

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Отлично ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='h24'></a>
# #### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
rating_na = actual_data.groupby(['rating']).agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5)

rating_eu = actual_data.groupby(['rating']).agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5)

rating_jp = actual_data.groupby(['rating']).agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5)

# %%
rating_na
# Out:
#              na_sales
# rating
# M              165.21
# not entered     89.42
# E               79.05
# E10+            54.24
# T               49.79

# %%
rating_eu
# Out:
#              eu_sales
# rating
# M              145.32
# E               83.36
# not entered     78.91
# E10+            42.69
# T               41.95

# %%
rating_jp
# Out:
#              jp_sales
# rating
# not entered     85.05
# T               20.59
# E               15.14
# M               14.11
# E10+             5.89

# %%
rating_na.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_eu.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_jp.plot(kind='bar', figsize=(15,5), ec='black')
# Out:
# <AxesSubplot:xlabel='rating'>

# %% [markdown]
# <s>В Северной Америке и в Европе картина практически одинаковая. Во всех регионах больше всего с игр с рейтингом "E".

# %% [markdown]
# В Северной Америке и в Европе картина практически одинаковая. Во всех регионах больше всего с игр с рейтингом "M", 'not entered' и 'E' делять второе и третье место игры с рейтингом E10+ и T на 4 или 5 месте
#
# В Японии игры жанра 'not_entered' Супер популяры, а заними почти с разницев в 4 раз в меньшую сторону игры с рейтингом "T"<br>
# Игры с рейтингом E10+ в Японии тоже не популярны.<br>
# Возможно в японии другая система рейтинга игр большя обширна и  поэтому они не вошли в стандарный список.

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.2 ✔️:</b>
#
# Да, ты прав, там CERO 😎
#
# </div>
# </div>

# %% [markdown]
# <a id='h25'></a>
# ### Проверьте гипотезы

# %% [markdown]
# <a id='h26'></a>
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# H0 (нулевая гипотеза) - средние пользовательские рейтинги  Xbox One и PC одинаковые
#
# H1 (альтернативная гипотеза) - средние пользовательские рейтинги Xbox One и PC разные

# %%
PC = actual_data[(actual_data['platform'] == 'PC') & (actual_data['user_score'] > 0)]['user_score']
XONE = actual_data[(actual_data['platform'] == 'XONE') & (actual_data['user_score'] > 0)]['user_score']

# %%
alpha = 0.1

# %%
result = st.ttest_ind(PC, XONE)

# %%
print('p-значение:', result.pvalue)

if (result.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **На имеющихся данных, на уровне значимости 0.1, нет оснований отвергать нулевую гипотезу, что средние пользовательские рейтинги Xbox One и PC одинаковые**

# %%
actual_data[actual_data['platform'] == 'PC']['user_score'].mean()
# Out:
# 4.961904761904762

# %%
actual_data[actual_data['platform'] == 'XONE']['user_score'].mean()
# Out:
# 4.542105263157895

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Гипотезы сформулированы и проверены верно 😉 Молодец, что вывел средние выборок для проверки
#
# </div>
# </div>

# %% [markdown]
# <a id='h27'></a>
# #### Средние пользовательские рейтинги жанров Action  и Sports разные.

# %% [markdown]
# H0 (нулевая гипотеза) -  средний пользовательский рейтинг жанров Action и Sports одинаковый
#
# H1 (альтернативная гипотеза) - средний пользовательский рейтинг жанров Action и Sports рызный

# %%
act = actual_data[(actual_data['genre'] == 'Action') & (actual_data['user_score'] > 0)]['user_score']
sport = actual_data[(actual_data['genre'] == 'Sports') & (actual_data['user_score'] > 0)]['user_score']

# %%
result2 = st.ttest_ind(act, sport)

# %%
print('p-значение:', result2.pvalue)

if (result2.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %%
### Верно следующее утверждение: средний пользовательский рейтинг жанров Action и Sports одинаковый

# %% [markdown]
# **На основании имеющихся данных, на уровне значимости 0.1, есть основания отвергнуть нулевую гипотезу, средний пользовательский рейтинг жанров Action и Sports одинаковый**

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Гипотезы сформулированы и проверены верно 😉
#
# </div>
# </div>

# %% [markdown]
# <a id='h28'></a>
# ### Общий вывод

# %% [markdown]
# <h1>Вывод

# %% [markdown]
# На выручку и продажи в игровой индустрии оценки критиков и пользователей почти не влияют.  Между оценками пользователей и критиков есть небольшая связь.
#
# Самый прибыльные платформы за последнее время это платформы вышедшие недавно '3DS','PS4','XONE', их предыдущие версии уже не приносят много прибыли.
#
# Самый прибыльный и популярный жанр Action, второй в рейтинге по продажам и сумме Shooter,но у Shooter меньше кол-во игры. Игры с жанром Adventure и имеею среднее кол-во продаж, но маленькую прибыли, наверное это связанной с ценой за копию. Худшие по продажам и прибыли игры жанра Puzzle.
# А в среднем одна игра жанра Shooter приносит почти в 3 раза больше прибыли,а игра жанра sports в 1.5 больше жанра самого полярного жанра Action, который занимает средние показатели по продажам за игру. Ну Жанр худщий по прибыли за игру Adventure можно сказать, что не приносит денег.
#
# Азиатский рынок имеет свои предпочтения по жанрам игр и приставкам и рейтинга.
#
# **По приставкам:**<br>
# В Северной Америке популярны приставки PS4 и XONE. Немного отстает x360. Топ-4 PS3 и топ-5 3DS соответственно.<br>
# В Европе cупер популярна Ps4, на втором месте предыдущая версия приставки ps3. с почти одинаковой популярностью X360, XONE, а 3DS топ-5.<br>
# В Японии супер популярен 3DS, дальше PS3 и PSV. топ-4 и топ-5 PS4 и WIIU соответственно. На Азиатском рынке наблюдаются другие тенденции.<br>
#
# **Жанру:**<br>
# В Северной Америке самые популярные игры жанра Action и Shooter, дальше Sports, Role-Playing и Misc
# В Европе самые популярные игры жанра Action и Shooter, дальше Sports, Role-Playing и Racing
# В Японии с большим отрывом популярен Role-Playing, примерно на равных показателях Action, и топ 3-5 Sports, fighting, Misc.<br>
# Ну опять же особенности Азиатского рынка
#
# **рейтингу:**<br>
# В Северной Америке и в Европе картина практически одинаковая. Во всех регионах больше всего с игр с рейтингом "M", 'not entered' и 'E' делят второе и третье место игры с рейтингом E10+ и T на 4 или 5 месте
# В Японии игры жанра 'not_entered' Супер популяры, а заним почти с разницей в 4 раз в меньшую сторону игры с рейтингом "T"<br>
# Игры с рейтингом E10+ в Японии тоже не популярны.<br>
#
# **В целом:**
# По графикам продаж в игровой индустрии видно, что продажи в игровой индустрии в послееднее время падают.
#
# Тут можно предположить, что на продажи следующие факторы:<br>
# Предоставлять много игры по подписке( пример PS PLUS), следовательно теряется смысл покупать игры отдельно.<br>
# Развитие Пиратства, взломщики игр не сидят сложа руки.<br>
# Появление игр с дополнениями(DLC), вместо выхода полноценной новой игры.<br>
# А также в последнее время компании все чаще для получение  прибыли используют микротразакции<br>
#
# Также проверили две гипотезы и установили, что:<br>
# На имеющихся данных, на уровне значимости 0.1, нет оснований отвергать нулевую гипотезу, что средние пользовательские рейтинги Xbox One и PC одинаковые
#
# На основании имеющихся данных, на уровне значимости 0.1, нет оснований отвергать нулевую гипотезу, средний пользовательский рейтинг жанров Action и Sports одинаковый

# %% [markdown]
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
# <b>Комментарий ревьюера V.3 ✔️:</b>
#
# Отличный итоговый вывод, в котором отражены все основные закономерности и результаты, полученные в ходе исследования ⭐
#
# </div>
# </div>

# %% [markdown]
# <a id='result-1'></a>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid black; padding: 15px;">
# <s>Итог. Комментарий ревьюера: </b>
#
# В проекте мне очень понравились следующие моменты:
#
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-success">
#
# ✔️ Проект имеет чёткую структуру, код имеет хорошую логику и мало повторений;
#
# ✔️ Верно сформулированы гипотезы;
#
#
# </div>
# </div>
#
# Моменты, которые нужно исправить:
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
#
# ❌ В вводной части отсутствует содержание;
#
# ❌ Отсутствуют первичные выводы после загрузки данных и не сформирован план предобработки данных;
#
# ❌ Отсутствует обоснование некоторых действий с данными;
#
# ❌ Не обработаны пропуски в rating;
#
# ❌ По некоторым графикам возможны разночтения;
#
# ❌ Неверно определён актуальный период для анализа;
#
# ❌ Неверно определены потенциально прибыльные платформы;
#
# ❌ Анализ проводится по всем данным, а не по данным за актуальный период по выбранным консолям;
#
# ❌ Не рассмотрены средние/медианные продажи по жанрам;
#
# ❌ Неверно сформулированы выводы по исследованию гипотез;
#
# ❌ Больше 3-х жёлтых комментариев;
#
# ❌ После всех исправлений необходимо обновить некоторые выводы;
#
# </div>
# </div>
# <hr>
# Верю, что ты со всем справишься! Если появятся вопросы, буду рад на них ответить. С нетерпением жду проект на повторную проверку!
# </div>

# %% [markdown]
# <a id='result-2'></a>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid black; padding: 15px;">
# <s>Итог. Комментарий ревьюера V.2: </b>
#
# Моменты, которые нужно исправить:
# <div style="border-radius: 3px; border: 2px solid black; padding: 0px;">
# <div class="alert alert-danger">
#
# ❌ По некоторым графикам возможны разночтения;
#
# ❌ Не до конца определены потенциально прибыльные платформы;
#
# ❌ Анализ проводится по всем данным, а не по данным за актуальный период по выбранным консолям;
#
# ❌ После всех исправлений необходимо обновить выводы;
#
# </div>
# </div>
# <hr>
# Верю, что ты со всем справишься! Если появятся вопросы, буду рад на них ответить. С нетерпением жду проект на повторную проверку!
# </div>

# %% [markdown]
# <a id='benefit'></a>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid black; padding: 15px;">
# <b>Итог. Комментарий ревьюера V.3: </b>
#
# В итоге получилась очень сильная работа! Видно, что вложено много труда, осознанность присутствует в каждой фразе и в каждом действии! Очень редко встречаются подобные проекты, которые хочется снова перечитать и ставить в пример остальным студентам! Надеюсь, что ты продолжишь использовать такой подход и после перенесёшь в работу, где, я уверен, у тебя всё получится! ⭐⭐⭐⭐⭐
#
# **P.s.** Такой комментарий я пишу крайне редко, если работа действительно произвела на меня впечатление
#
# Проект принят, поздравляю, было очень приятно с тобой поработать! Надеюсь, что смог помочь тебе сделать ещё один шаг на пути обучения, в котором желаю тебе удачи и больших успехов!
#
# </div>
